# %%
import pandas as pd
#import mathplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r"sales_data.csv")

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# # ```Mathplotlib``` and ```Seaborn```
# both are used for ```Data visualisation```
# > In short ```Seaborn``` built on top of ```Mathpoltlib```, it's superset of it

# %%
sns.relplot(data=df, x=df['Country'], y=df['Profit'], kind='line')
